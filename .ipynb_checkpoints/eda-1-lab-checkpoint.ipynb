# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %matplotlib inline

# %%
file_path = r"C:\Users\Eros\Desktop\amz_uk_price_prediction_dataset.csv"
am_data = pd.read_csv(file_path, encoding='utf-8')
am_data
# Out:
#              uid        asin  \
# 0              1  B09B96TG33
# 1              2  B01HTH3C8S
# 2              3  B09B8YWXDF
# 3              4  B09B8T5VGV
# 4              5  B09WX6QD65
# ...          ...         ...
# 2443646  2828589  B0CHSD7P2Q
# 2443647  2828590  B0B7B8FNBQ
# 2443648  2828591  B0BD5FL5FB
# 2443649  2828592  B008OYLL4I
# 2443650  2828593  B08P3W9B3T
#
#                                                      title  stars  reviews  \
# 0        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 1        Anker Soundcore mini, Super-Portable Bluetooth...    4.7    98099
# 2        Echo Dot (5th generation, 2022 release) | Big ...    4.7    15308
# 3        Echo Dot with clock (5th generation, 2022 rele...    4.7     7205
# 4        Introducing Echo Pop | Full sound compact Wi-F...    4.6     1881
# ...                                                    ...    ...      ...
# 2443646  Motorbike Armour, Motorbike Clothing, Cycling ...    0.0        0
# ...

# %%
# Part 1:

# %%
category_freq = data['category'].value_counts()
top_5_categories = category_freq.head(5)
top_5_categories
# Out:
# category
# Sports & Outdoors                         836265
# Beauty                                     19312
# Handmade Clothing, Shoes & Accessories     19229
# Bath & Body                                19092
# Birthday Gifts                             18978
# Name: count, dtype: int64

# %%
top_5_categories = category_freq.head()
plt.figure(figsize=(10,6))
top_10_categories.plot(kind='bar')
plt.title('Distribution of Products in the 5 Most Frequent Categories')
plt.xlabel('Product Category')
plt.ylabel('Frequency')
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize=(8,8))
top_5_categories.plot(kind='pie', autopct='%1.1f%%')
plt.title('Proportion of the 5 Most Listed Product Categories')
plt.ylabel('')
plt.show()

# %%
# Part 2:

# %%
mean_price = data['price'].mean()
median_price = data['price'].median()
mode_price = data['price'].mode()[0]

mean_price, median_price, mode_price
# Out:
# (89.24380943923663, 19.09, 9.99)

# %%
variance_price = data['price'].var()
std_dev_price = data['price'].std()
range_price = data['price'].max() - data['price'].min()
iqr_price = data['price'].quantile(0.75) - data['price'].quantile(0.25)

variance_price, std_dev_price, range_price, iqr_price
# Out:
# (119445.48532256528, 345.60886175352226, 100000.0, 36.0)

# %%
plt.figure(figsize=(10,6))
plt.hist(data['price'], bins=50, edgecolor='k')
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
# Filter prices to exclude outliers
filtered_data = data[data['price'] <= 1000]

# Histogram with filtered data
plt.figure(figsize=(10,6))
plt.hist(filtered_data['price'], bins=50, edgecolor='k')
plt.title('Distribution of Product Prices (≤ 1000)')
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.show()

# %%
plt.figure(figsize=(8,6))
plt.boxplot(data['price'], vert=False)
plt.title('Distribution of Product Prices')
plt.xlabel('Price')
plt.show()

# %%
# Part 3:

# %%
mean_stars = data['stars'].mean()
median_stars = data['stars'].median()
mode_stars = data['stars'].mode()[0]

mean_stars, median_stars, mode_stars
# Out:
# (2.152836472966065, 0.0, 0.0)

# %%
unique_values = data['stars'].unique()
unique_values
value_counts = data['stars'].value_counts()
value_counts
# Out:
# stars
# 0.0    1225641
# 4.5     151577
# 4.6     136995
# 4.4     136165
# 5.0     128492
# 4.3     112564
# 4.7      94566
# 4.2      86871
# 4.0      66089
# 4.1      65115
# 4.8      41858
# 3.9      36555
# 3.8      27876
# 3.7      21137
# 3.6      16219
# 3.5      14673
# 3.0      12819
# 4.9      11081
# 3.4      10355
# 1.0       8484
# 3.3       8269
# 3.2       5771
# 3.1       4679
# 2.0       3901
# 2.9       3341
# 2.8       2306
# 2.7       2104
# 2.5       2103
# 2.6       1579
# 2.4       1060
# 2.3        734
# 2.2        602
# 2.1        540
# 1.5        404
# 1.9        300
# 1.8        249
# 1.7        177
# 1.4        149
# 1.6        147
# 1.3         78
# 1.2         23
# 1.1          3
# Name: count, dtype: int64

# %%
filtered_stars = data[data['stars'] > 0]

mean_stars = filtered_stars['stars'].mean()
median_stars = filtered_stars['stars'].median()
mode_stars = filtered_stars['stars'].mode()[0]

mean_stars, median_stars, mode_stars
# Out:
# (4.31916076222691, 4.4, 4.5)

# %%
variance_stars = data['stars'].var()
std_dev_stars = data['stars'].std()
iqr_stars = data['stars'].quantile(0.75) - data['stars'].quantile(0.25)

variance_stars, std_dev_stars, iqr_stars
# Out:
# (4.81743402976196, 2.1948653785054697, 4.4)

# %%
skewness_stars = data['stars'].skew()
kurtosis_stars = data['stars'].kurt()

skewness_stars, kurtosis_stars
# Out:
# (0.08120735761080985, -1.9260061280432985)

# %%
plt.figure(figsize=(10,6))
plt.hist(data['stars'], bins=10, edgecolor='k')
plt.title('Distribution of Product Ratings')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()

# %%
# Filtrar los valores cero
filtered_stars = data[data['stars'] > 0]

# Histograma de la distribución de calificaciones sin los ceros
plt.figure(figsize=(10,6))
plt.hist(filtered_stars['stars'], bins=10, edgecolor='k')
plt.title('Distribution of Product Ratings (Excluding Zeros)')
plt.xlabel('Rating')
plt.ylabel('Frequency')
plt.show()
